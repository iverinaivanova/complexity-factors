# %% [markdown]
# <a href="https://colab.research.google.com/github/iverinaivanova/complexity-factors/blob/main/%20complexity-factors/retrieval-compl-factors/supplements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -m spacy download en_core_web_trf
# Out:
# Collecting en-core-web-trf==3.7.3
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.7.3/en_core_web_trf-3.7.3-py3-none-any.whl (457.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.4/457.4 MB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.11/dist-packages (from en-core-web-trf==3.7.3) (3.7.5)
# Collecting spacy-curated-transformers<0.3.0,>=0.2.0 (from en-core-web-trf==3.7.3)
#   Downloading spacy_curated_transformers-0.2.2-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.10.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.26.4)
# Collecting curated-transformers<0.2.0,>=0.1.0 (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3)
#   Downloading curated_transformers-0.1.1-py2.py3-none-any.whl.metadata (965 bytes)
# Collecting curated-tokenizers<0.1.0,>=0.0.9 (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3)
#   Downloading curated_tokenizers-0.0.9-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Requirement already satisfied: torch>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2.6.0+cu124)
# Requirement already satisfied: regex>=2022 in /usr/local/lib/python3.11/dist-packages (from curated-tokenizers<0.1.0,>=0.0.9->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2024.11.6)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2025.1.31)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.1.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.1.2)
# Downloading spacy_curated_transformers-0.2.2-py2.py3-none-any.whl (236 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.3/236.3 kB 4.4 MB/s eta 0:00:00
# Downloading curated_tokenizers-0.0.9-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (735 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 735.6/735.6 kB 18.0 MB/s eta 0:00:00
# Downloading curated_transformers-0.1.1-py2.py3-none-any.whl (25 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 58.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 18.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 24.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 65.8 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, curated-tokenizers, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, curated-transformers, spacy-curated-transformers, en-core-web-trf
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed curated-tokenizers-0.0.9 curated-transformers-0.1.1 en-core-web-trf-3.7.3 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 spacy-curated-transformers-0.2.2
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

# Load the transformer-based English model
nlp = spacy.load("en_core_web_trf")

# %%
from spacy.tokens import Span
import re

def has_clausal_supplement(doc):
    """
    Check if a clause contains a clausal supplement (parenthetical), including relative clauses and parataxis.
    Returns 1 if a supplement is found, 0 otherwise.
    """
    # Look for punctuation that might indicate a parenthetical (commas, dashes, parentheses)
    punctuation_marks = {',', '—', '(', ')', '_', '--'}
    has_punctuation = any(token.text in punctuation_marks for token in doc)

    if not has_punctuation:
        return 0

    # Dependency-based detection
    for token in doc:
        # Non-restrictive relative clauses (relcl)
        if token.dep_ == "relcl":
            left_idx = token.left_edge.i
            right_idx = token.right_edge.i
            if left_idx > 0 and right_idx < len(doc) - 1:
                left_punct = doc[left_idx - 1].text.strip()
                right_punct = doc[right_idx + 1].text.strip()
                # Check for comma, dash, or parentheses boundaries
                if (left_punct == ',' and right_punct == ',') or \
                   (left_punct == '—' and right_punct == '—') or \
                   (left_punct == '(' and right_punct == ')'):
                    # Verify it starts with a relative pronoun (who, which, that, etc.)
                    subtree = list(token.subtree)
                    if subtree and subtree[0].text.lower() in {"who", "whom", "which"}:
                        return 1
                    # Check for preposition + relative pronoun (e.g., "of which")
                    elif len(subtree) > 1 and subtree[1].text.lower() in {"who", "whom", "which"} \
                         and subtree[0].pos_ == "ADP":
                        return 1

        # Paratactic parenthetical clauses
        elif token.dep_ == "parataxis":
            subtree = list(token.subtree)
            left_idx = subtree[0].i
            right_idx = subtree[-1].i
            if left_idx > 0 and right_idx < len(doc) - 1:
                left_punct = doc[left_idx - 1].text.strip()
                right_punct = doc[right_idx + 1].text.strip()
                if (left_punct == ',' and right_punct == ',') or \
                   (left_punct == '—' and right_punct == '—') or \
                   (left_punct == '(' and right_punct == ')'):
                    return 1

    # Fallback: Text-based pattern matching for short parentheticals
    text = doc.text
    pattern = r',\s*[A-Za-z\s]{1,20}\s*,'
    matches = re.finditer(pattern, text)
    for match in matches:
        span_text = match.group().strip(', ').strip()
        span_words = span_text.split()
        if len(span_words) <= 5:  # Short clause heuristic
            span_doc = nlp(span_text)
            has_verb = any(token.pos_ == "VERB" for token in span_doc)
            if has_verb:  # Likely a clause
                return 1

    return 0

# %%
def process_sentences(input_file, output_file):
    """
    Process sentences from the input file and determine the presence or absence of negation markers.
    Write the results to the output file with two columns: sentence and supplement (0 or 1).
    """
    with open(input_file, "r", encoding="utf-8") as infile, \
         open(output_file, "w", encoding="utf-8") as outfile:

        # Write header to the output file
        outfile.write("clause\tsupplement\n")

        # Process each line in the input file
        for line in infile:
            # Strip leading/trailing whitespace
            sentence = line.strip()

            # Skip empty lines
            if not sentence:
                continue

            # Parse the sentence with spaCy
            doc = nlp(sentence)

            supplements = has_clausal_supplement(doc)

            # Write the result to the output file
            outfile.write(f"{sentence}\t{supplements}\n")

            # Print the result to the console
            print(f"Clause: {sentence}")
            print(f"Clausal Supplement: {supplements}\n")


    print(f"Results have been written to {output_file}")

# That-Clauses
input_file = "/sample_supplements.txt"
output_file = "/supplements_that-cl.tsv"

# To-Inf
# input_file = "/all-nonfinCC-very-final-no-infm.txt"  # Replace with your input file path
# output_file = "/supplements_to-inf.tsv"  # Replace with your desired output file path
process_sentences(input_file, output_file)
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
#
# Clause: To get five inches of rain in two hours.
# Clausal Supplement: 0
#
# Clause: That he can see this as a great hardship but not a martyrdom.
# Clausal Supplement: 0
#
# Clause: To make it into a Christian site with crosses raised high.
# Clausal Supplement: 0
#
# Clause: That the financial community is firmly supportive of our project.
# Clausal Supplement: 0
#
# Clause: To do away with a regulatory body that has been operational for the last 50 years and that even Europe.
# Clausal Supplement: 0
#
# Clause: To play Argentina.
# Clausal Supplement: 0
#
# Clause: To be able to go back to back like that.
# Clausal Supplement: 0
#
# Clause: To be number one in our group.
# Clausal Supplement: 0
#
# Clause: To see how cool and how calculated this guy really is at that age , how big a surprise.
# Clausal Supplement: 0
#
# Clause: To gain such a big advantage.
# Clausal Supplement: 0
#
# Clause: To look back at the responses that the murder evoked from the literary and political intelligentsia.
# Clausal Supplement: 0
#
# Clause: That the hospital is in bad financial shape.
# Clausal Supplement: 0
#
# Clause: To date no final casualties.
# Clausal Supplement: 0
#
# Clause: To try to deny him these emotions or refute the validity of his feelings.
# Clausal Supplement: 0
#
# Clause: To stand in the scarred old forecourt of Grauman 's Egyptian Theater.
# Clausal Supplement: 0
#
# Clause: To take political advantage of political prisoners.
# Clausal Supplement: 0
#
# Clause: That a ` ` smackdown '' politician like Ventura sits today in the governor 's chair.
# Clausal Supplement: 0
#
# Clause: To suddenly come across a tape of an unknown band of teen - age musicians playing in a small town 37 years after the fact.
# Clausal Supplement: 0
#
# Clause: That it 's a sympathetic portrait of the usually demonized producer , Wright says ,.
# Clausal Supplement: 1
#
# Clause: To have a night that 's all about me.
# Clausal Supplement: 0
#
# Clause: To learn about the spirit of a time through artworks.
# Clausal Supplement: 0
#
# Clause: To happen to our closer.
# Clausal Supplement: 0
#
# Clause: To say that Wilt Chamberlain might have had an excuse for a subpar night -LRB- by his standards , anyway -RRB- in this neutral - site game between his Philadelphia Warriors and the New York Knicks.
# Clausal Supplement: 0
#
# Clause: To have a group of animals under such a high level of threat.
# Clausal Supplement: 0
#
# Clause: To have accomplished that in a mainstream studio filmmaking environment.
# Clausal Supplement: 0
#
# Clause: To have a power forward like that.
# Clausal Supplement: 0
#
# Clause: That Sony Pictures Classics should be heading in that direction.
# Clausal Supplement: 0
#
# Clause: To go out and give our club a chance to win all year.
# Clausal Supplement: 0
#
# Clause: To find your own voice in that family.
# Clausal Supplement: 0
#
# Clause: To be able to do what I.
# Clausal Supplement: 0
#
# Clause: To pretend the entire nation loves Saddam Hussein and voted for him.
# Clausal Supplement: 0
#
# Clause: That this report had to be written.
# Clausal Supplement: 0
#
# Clause: To take that away from him.
# Clausal Supplement: 0
#
# Clause: That she was named for Martina Navratilova , who defected from Czechoslovakia because she feared her tennis career would atrophy there ,.
# Clausal Supplement: 1
#
# Clause: To spend some time in his company.
# Clausal Supplement: 0
#
# Clause: To be a member of the Upper Class.
# Clausal Supplement: 0
#
# Clause: That the ceremony is being dwarfed by Bird 's return.
# Clausal Supplement: 0
#
# Clause: That it is remembered at all today.
# Clausal Supplement: 0
#
# Clause: To look at the people who ' ve been on the red carpet with me ,   he says , ` `.
# Clausal Supplement: 1
#
# Clause: To protect the public , I have made a new control order , however inevitably this.
# Clausal Supplement: 0
#
# Clause: To deny a medically necessary procedure for a woman.
# Clausal Supplement: 0
#
# Clause: To challenge children
# Clausal Supplement: 0
#
# Clause: That the winner turned out to be Stuart Appleby.
# Clausal Supplement: 0
#
# Clause: To see it on television.
# Clausal Supplement: 0
#
# Clause: To write a book.
# Clausal Supplement: 0
#
# Clause: To get this result so far.
# Clausal Supplement: 0
#
# Clause: To go on the same park as them and get a point.
# Clausal Supplement: 0
#
# Clause: That the first thing visitors see is a call for enlightenment -- the work of the Chinese artist Xu Zhen --.
# Clausal Supplement: 0
#
# Clause: To win the Masters as my first title.
# Clausal Supplement: 0
#
# Clause: To give up on Iraq.
# Clausal Supplement: 0
#
# Clause: To be able to still be under 51.
# Clausal Supplement: 0
#
# Clause: That the site is nonfunctional.
# Clausal Supplement: 0
#
# Clause: To maintain social and human security in a period of challenges and change.
# Clausal Supplement: 0
#
# Clause: To say that was the last one.
# Clausal Supplement: 0
#
# Clause: To beat the World Cup leader in his specialty.
# Clausal Supplement: 0
#
# Clause: That such a situation could be tolerated in the nineteenth century.
# Clausal Supplement: 0
#
# Clause: To be mentioned in the same category.
# Clausal Supplement: 0
#
# Clause: To have someone different.
# Clausal Supplement: 0
#
# Clause: To be selected for Brazil.
# Clausal Supplement: 0
#
# Clause: To watch him instructing younger sandhogs.
# Clausal Supplement: 0
#
# Clause: That these young Muslims are n't depicted as frenzied devotees of a madrassa.
# Clausal Supplement: 0
#
# Clause: To be up here with these guys.
# Clausal Supplement: 0
#
# Clause: To be a virgin now.
# Clausal Supplement: 0
#
# Clause: To contemplate the possibility of a treaty coming into force whose parties do not include several or even any one of the eight nuclear - capable states , such a treaty.
# Clausal Supplement: 0
#
# Clause: To push candidates for answers on touchy racial issues.
# Clausal Supplement: 0
#
# Clause: To make a star - studded album , however ,.
# Clausal Supplement: 0
#
# Clause: That the business market is where push is most likely to gain a foothold.
# Clausal Supplement: 0
#
# Clause: To disallow them from withdrawing their savings upon leaving their Singapore jobs and returning to Malaysia can not.
# Clausal Supplement: 0
#
# Clause: That this particular body of water is occupied by monstrous - looking creatures that have changed very little in 80 million years apparently.
# Clausal Supplement: 0
#
# Clause: To refuse the vaccination.
# Clausal Supplement: 0
#
# Clause: To make cash available to their husbands.
# Clausal Supplement: 0
#
# Clause: To shoot 68 the first two days.
# Clausal Supplement: 0
#
# Clause: That the committee was split.
# Clausal Supplement: 0
#
# Clause: To have a man of esteem and power honor women in this way.
# Clausal Supplement: 0
#
# Clause: That he is under pressure from Amazonian governors to end their isolation and link them with the outside world.
# Clausal Supplement: 0
#
# Clause: That the Belgians and the French opted for humor while the British played it straight.
# Clausal Supplement: 0
#
# Clause: To say the last few weeks have been difficult for Gator sophomore linebacker Earl Everett.
# Clausal Supplement: 0
#
# Clause: That the skaters look and feel good.
# Clausal Supplement: 0
#
# Clause: To say his religion is irrelevant.
# Clausal Supplement: 0
#
# Clause: To help those who help others.
# Clausal Supplement: 0
#
# Clause: To bomb first and ask questions later ,   he said ,.
# Clausal Supplement: 1
#
# Clause: To build this country.
# Clausal Supplement: 0
#
# Clause: To read through 100 years of The New Times Book Review ,   its editor , Charles McGrath , writes in his introduction to   Books of the Century ,   .
# Clausal Supplement: 0
#
# Clause: To be openly proper and conventional yet also openly daring.
# Clausal Supplement: 0
#
# Clause: To be here tonight and see all this talent and love for the Lord.
# Clausal Supplement: 0
#
# Clause: To hear RoboCop quote Hemingway.
# Clausal Supplement: 0
#
# Clause: To say he was in the Mets ' plans.
# Clausal Supplement: 0
#
# Clause: That she did n't have a lick of talent.
# Clausal Supplement: 0
#
# Clause: To get us to two Final Fours with their leadership.
# Clausal Supplement: 0
#
# Clause: That it plays like a shiny , garish TV sitcom with an abundance of ebullient personalities.
# Clausal Supplement: 0
#
# Clause: To talk to the doctors and nurses and patients who have been using this method over the last few years.
# Clausal Supplement: 0
#
# Clause: To have the status he 's got without it , I think ,.
# Clausal Supplement: 1
#
# Clause: To commemorate her visit , 1 million trees.
# Clausal Supplement: 0
#
# Clause: To sculpt Fulham in a similar fashion.
# Clausal Supplement: 0
#
# Clause: To use it as a crutch.
# Clausal Supplement: 0
#
# Clause: To get in at five under.
# Clausal Supplement: 0
#
# Clause: To be denied for many of them.
# Clausal Supplement: 0
#
# Clause: To enter a theater.
# Clausal Supplement: 0
#
# Clause: To add the prop of government capital infusions.
# Clausal Supplement: 0
#
# Clause: To embrace deeper and more solid ways of recognizing and trusting each other.
# Clausal Supplement: 0
#
# Clause: To say the people here are revved up about this game.
# Clausal Supplement: 0
#
# Clause: That a player so short on competition could win a Grand Slam event.
# Clausal Supplement: 0
#
# Clause: That the Games have become too big.
# Clausal Supplement: 0
#
# Clause: To write from a different gender 's viewpoint.
# Clausal Supplement: 0
#
# Clause: To have actually gotten out , -LRB- Gurule -RRB-.
# Clausal Supplement: 0
#
# Clause: To continue without results.
# Clausal Supplement: 0
#
# Clause: To say Bobby Ramos is excited about his new job as a Devil Rays coach.
# Clausal Supplement: 0
#
# Clause: To get Raybestos Rookie of the Year.
# Clausal Supplement: 0
#
# Clause: That they were even talking about it.
# Clausal Supplement: 0
#
# Clause: That the first two courts have granted Tempo 's appeal.
# Clausal Supplement: 0
#
# Clause: To use the sport 's own lingua franca ,   First Descent   just.
# Clausal Supplement: 0
#
# Clause: That they lost the World Series to the Detroit Tigers in five games.
# Clausal Supplement: 0
#
# Clause: To be singled out in such a strong year.
# Clausal Supplement: 0
#
# Clause: To win six times -LRB- in 1 -LCB- years as a pro -RRB- , to win the Masters at this stage of his career , with the competition from so many great young players , to accomplish what he has ,.
# Clausal Supplement: 0
#
# Clause: To hold anyone back.
# Clausal Supplement: 0
#
# Clause: To do it once like that.
# Clausal Supplement: 0
#
# Clause: To reject his bravura pictures of the late 1940s and early 1950s in particular.
# Clausal Supplement: 0
#
# Clause: To get -LRB- the spacewalk -RRB- behind us.
# Clausal Supplement: 0
#
# Clause: That he did it as a black man during the Jim Crow era of segregation and racism ,.
# Clausal Supplement: 0
#
# Clause: To score three goals away in Europe.
# Clausal Supplement: 0
#
# Clause: To say that in the safety of your house.
# Clausal Supplement: 0
#
# Clause: To get 25 percent of the voting public to sign a petition.
# Clausal Supplement: 0
#
# Clause: To call it a hatchet job.
# Clausal Supplement: 0
#
# Clause: To say this is a pressure - packed time for schools and families.
# Clausal Supplement: 0
#
# Clause: That the Cowboys ' star would eventually become the league 's all - time rushing king has pretty much.
# Clausal Supplement: 0
#
# Clause: That it might not be sensational enough for modern tabloid tastes.
# Clausal Supplement: 0
#
# Clause: That a world - weary cop promises to find a killer on his last day on the job.
# Clausal Supplement: 0
#
# Clause: To know what 's at stake in the Arctic National Wildlife Refuge.
# Clausal Supplement: 0
#
# Clause: To lose that support.
# Clausal Supplement: 0
#
# Clause: To have this team play well like we did and.
# Clausal Supplement: 0
#
# Clause: To hear Broncos ' receiver Rod Smith tell it , their No . 3 wideout.
# Clausal Supplement: 0
#
# Clause: To get the win and fly home and have a -LRB- bye -RRB- week off.
# Clausal Supplement: 0
#
# Clause: To portray her as a wallflower that nobody.
# Clausal Supplement: 0
#
# Clause: To have someone who can bridge ancient religious texts with current events.
# Clausal Supplement: 0
#
# Clause: To say this is a solution to our problem.
# Clausal Supplement: 0
#
# Clause: To come so close already at my age.
# Clausal Supplement: 0
#
# Clause: To see something new.
# Clausal Supplement: 0
#
# Clause: To talk about a tax cut when you 're talking about a deficit budget.
# Clausal Supplement: 0
#
# Clause: To go top of the championship.
# Clausal Supplement: 0
#
# Clause: To suggest that these negotiations are on the point of collapse.
# Clausal Supplement: 0
#
# Clause: To win on this field.
# Clausal Supplement: 0
#
# Clause: That the brand name.
# Clausal Supplement: 0
#
# Clause: To say this was a tough loss.
# Clausal Supplement: 0
#
# Clause: That the Packers can still talk about the playoffs after slipping to 5 - 7.
# Clausal Supplement: 0
#
# Clause: To remain unbeaten.
# Clausal Supplement: 0
#
# Clause: To sum up , MillatFacebook.
# Clausal Supplement: 0
#
# Clause: To announce a big - number target.
# Clausal Supplement: 0
#
# Clause: To imply that the prosecution is a plot by the West.
# Clausal Supplement: 0
#
# Clause: To say that a political solution is not possible.
# Clausal Supplement: 0
#
# Clause: To be a client.
# Clausal Supplement: 0
#
# Clause: To put another label on their saying , ` Drink more , '.
# Clausal Supplement: 0
#
# Clause: To surmise that the point of a name like Gay Dad is to make some statement about homosexuality or family values.
# Clausal Supplement: 0
#
# Clause: To have a map.
# Clausal Supplement: 0
#
# Clause: To call this exhibition process - oriented.
# Clausal Supplement: 0
#
# Clause: To presume that the conversation about the great religions starts with Christianity.
# Clausal Supplement: 0
#
# Clause: To get it right.
# Clausal Supplement: 0
#
# Clause: To have a supporter who had the confidence in the institution , and the curatorial staff to form something new , and the means to make a difference ,.
# Clausal Supplement: 0
#
# Clause: That the regulation ensnares some purely intrastate activity.
# Clausal Supplement: 0
#
# Clause: To say that it has never been hotter in Phoenix.
# Clausal Supplement: 0
#
# Clause: To create crime.
# Clausal Supplement: 0
#
# Clause: To finish second after such a dreadful qualifying.
# Clausal Supplement: 0
#
# Clause: To say I ' m befuddled.
# Clausal Supplement: 0
#
# Clause: To be safe in a grown - up seat belt , a child.
# Clausal Supplement: 0
#
# Clause: To suddenly put the responsibility for issues in Iraq on our agenda.
# Clausal Supplement: 0
#
# Clause: That the question should even arise just seven tournaments into the professional career of someone not yet 21 years old.
# Clausal Supplement: 0
#
# Clause: To describe the procedure.
# Clausal Supplement: 0
#
# Clause: To collect seven golds out of eight.
# Clausal Supplement: 0
#
# Clause: To bowl England out for 373 on that wicket , which is a magnificent batting wicket and a fast outfield.
# Clausal Supplement: 0
#
# Clause: To read most of Barthelme 's own non - fiction.
# Clausal Supplement: 0
#
# Clause: To hear many of Florida 's water gurus tell it , solving the state 's water problems.
# Clausal Supplement: 0
#
# Clause: That he is ready to test the knee in a game.
# Clausal Supplement: 0
#
# Clause: To take her away from us.
# Clausal Supplement: 0
#
# Clause: To have the opportunity to complete the -LRB- career -RRB- Grand Slam at the course where it all.
# Clausal Supplement: 0
#
# Clause: That they held off the Nazis longer than the Polish army.
# Clausal Supplement: 0
#
# Clause: To say we are n't concerned that someone might try to recruit the headquarters away from Colorado Springs.
# Clausal Supplement: 0
#
# Clause: To write honestly.
# Clausal Supplement: 0
#
# Clause: To know cheese grits.
# Clausal Supplement: 0
#
# Clause: To date many.
# Clausal Supplement: 0
#
# Clause: To have the chance to visit the memorial hall.
# Clausal Supplement: 0
#
# Clause: To elevate administrators to a privileged class.
# Clausal Supplement: 0
#
# Clause: To fail to understand this.
# Clausal Supplement: 0
#
# Clause: To travel from your home shores.
# Clausal Supplement: 0
#
# Clause: To do them individually in different years.
# Clausal Supplement: 0
#
# Clause: That they felt compelled to openly air such conclusions about a nominally close U.S. ally -- for which the administration is proposing billions in new aid dollars --.
# Clausal Supplement: 0
#
# Clause: To enforce a line of action , which seems like interference ,.
# Clausal Supplement: 0
#
# Clause: To say that the Spurs put up a weak fight.
# Clausal Supplement: 0
#
# Clause: That the case will ever get to court.
# Clausal Supplement: 0
#
# Clause: That it happened to come along when designers are newly infatuated with the 1980s.
# Clausal Supplement: 0
#
# Clause: That the wine could even be mentioned in the same breath with the Bordeaux giants.
# Clausal Supplement: 0
#
# Clause: That this comes at a time when women 's tennis is looking for a title sponsor capable of lavishing millions on it the way Virginia Slims once.
# Clausal Supplement: 0
#
# Clause: To treat mainland spouses equally.
# Clausal Supplement: 0
#
# Clause: To surrender your deliberations to vengeance.
# Clausal Supplement: 0
#
# Clause: To prevent flare - ups ,.
# Clausal Supplement: 0
#
# Clause: To have women trailing men -LRB- by that much -RRB-.
# Clausal Supplement: 0
#
# Clause: To walk out on it just as it was getting.
# Clausal Supplement: 0
#
# Clause: To have someone on the board who has been in the business of ferreting out false claims.
# Clausal Supplement: 0
#
# Clause: To deny history.
# Clausal Supplement: 0
#
# Clause: That he missed.
# Clausal Supplement: 0
#
# Clause: To say that the agreement is dead.
# Clausal Supplement: 0
#
# Clause: To win two in three years.
# Clausal Supplement: 0
#
# Clause: To say that Bibby is unaffected.
# Clausal Supplement: 0
#
# Clause: That he 's become public enemy No . 1.
# Clausal Supplement: 0
#
# Clause: To say a lot of people have been denied visas.
# Clausal Supplement: 0
#
# Clause: To gaze on the face of a 12 - year - old victim.
# Clausal Supplement: 0
#
# Clause: To come through the finish.
# Clausal Supplement: 0
#
# Clause: To be picked out of all the great accomplishments the U.S. delegation had in the Paralympics.
# Clausal Supplement: 0
#
# Clause: To do -- The Great Texas Balloon Race this weekend.
# Clausal Supplement: 0
#
# Clause: To show how your sense of humor can help you keep your senses _ not to mention your job _ here.
# Clausal Supplement: 0
#
# Clause: That the Angels even have a second half to look forward to.
# Clausal Supplement: 0
#
# Clause: To have Michael behind me.
# Clausal Supplement: 0
#
# Clause: To be able to see Cooperstown , Fenway Park and Yankee Stadium in five to seven days.
# Clausal Supplement: 0
#
# Clause: To have that type of swing in emotion in 13 seconds.
# Clausal Supplement: 0
#
# Clause: To score in a derby.
# Clausal Supplement: 0
#
# Clause: To watch   Il Mio Viaggio in Italia ,   Martin Scorsese 's monumental introduction to postwar Italian cinema ,.
# Clausal Supplement: 0
#
# Clause: That the creature was holding a green card.
# Clausal Supplement: 0
#
# Clause: To turn Fuhrman 's nastiness into a debate about whether white Americans are reluctant to own up to their own racism.
# Clausal Supplement: 0
#
# Clause: To preserve them from ` ` the dust heap   and the ` ` ruthlessness of time ,   to give their evanescent sweetness a presence in the present ,.
# Clausal Supplement: 0
#
# Clause: To have this rare opportunity.
# Clausal Supplement: 0
#
# Clause: To make matters more interesting -- not to mention more comic , sad , beautiful and ugly -- and in keeping with Hrebejk 's interest in nationalism , assimilation , otherness and the melting pot , Vera.
# Clausal Supplement: 0
#
# Clause: To have air marshals on flights between Indonesia and Singapore.
# Clausal Supplement: 0
#
# Clause: That the new nuclear power would be Iran , a giant nation in the Middle East , next door to Iraq ,.
# Clausal Supplement: 0
#
# Clause: To say the search for a new coach was messy.
# Clausal Supplement: 0
#
# Clause: That he is still able to find a drive - in.
# Clausal Supplement: 0
#
# Clause: That they get ratings and have loyal viewers.
# Clausal Supplement: 0
#
# Clause: That a star of Ms. Burnett 's age and reputation would return to the New York theater in a vehicle in which she is less than the cynosure.
# Clausal Supplement: 0
#
# Clause: To be this privileged , this white , this rich and be bitching about it ,   he says ,.
# Clausal Supplement: 1
#
# Clause: That the speaker rewarded so quickly was a former mayor of a city from another time zone.
# Clausal Supplement: 0
#
# Clause: To enter Charlie 's.
# Clausal Supplement: 0
#
# Clause: To revisit that memoir.
# Clausal Supplement: 0
#
# Clause: To demand that Wal - Mart 's foreign suppliers clean up their act.
# Clausal Supplement: 0
#
# Clause: To sit in its brutal seats and take in some Mahler.
# Clausal Supplement: 0
#
# Clause: To get a full debriefing , and presumably a truthful one ,.
# Clausal Supplement: 0
#
# Clause: That Japan is veering away from the potential benefits afforded by privatisation.
# Clausal Supplement: 0
#
# Clause: To gain the bid victory.
# Clausal Supplement: 0
#
# Clause: That the festival will end in a museum.
# Clausal Supplement: 0
#
# Clause: To open a Japanese - related art exhibit today 3B Akinori Iwamura.
# Clausal Supplement: 0
#
# Clause: To come out with the draw.
# Clausal Supplement: 0
#
# Clause: That the study of black holes could make for a popular planetarium show.
# Clausal Supplement: 0
#
# Clause: That they came here and took the airport.
# Clausal Supplement: 0
#
# Clause: To do something on a large scale like this.
# Clausal Supplement: 0
#
# Clause: That he lined that pitch to right - center field for a double , then added a pair of singles.
# Clausal Supplement: 0
#
# Clause: To be positive just.
# Clausal Supplement: 0
#
# Clause: That the Baltimore team that year was the Colts and this time is the Ravens.
# Clausal Supplement: 0
#
# Clause: To say she came from a broken home.
# Clausal Supplement: 0
#
# Clause: To end up winning the Premiership final as the culmination of his career.
# Clausal Supplement: 0
#
# Clause: To play and win every game.
# Clausal Supplement: 0
#
# Clause: That the rebel who did more than any other to spread the idea that all men are created equal never freed any of his own slaves -- except for Sally 's -LRB- and perhaps some of his -RRB- relatives --.
# Clausal Supplement: 0
#
# Clause: To report an unauthorized ordination of a woman priest , immediately press zero _ an inquisitor.
# Clausal Supplement: 0
#
# Clause: To now make the argument that we need do nothing ,   he said ,  .
# Clausal Supplement: 1
#
# Clause: To say it helps you.
# Clausal Supplement: 0
#
# Clause: To say that the vignette does not fully reflect the tenor of race relations in 1988 in Odessa.
# Clausal Supplement: 0
#
# Clause: To be unaware that one 's words tap into a monumental fear that exists in a portion of the electorate -- a fear that Obama 's race could get him killed --.
# Clausal Supplement: 0
#
# Clause: That it was BMW - Rolls Royce at the show.
# Clausal Supplement: 0
#
# Clause: That he chose the get - stoned route so often.
# Clausal Supplement: 0
#
# Clause: That she got a regular workout and a little extra pocket cash out of the arrangement.
# Clausal Supplement: 0
#
# Clause: That the roles are most naturally inhabited by actors who are friends or family.
# Clausal Supplement: 0
#
# Clause: To call Seattle University an underdog against Metro State.
# Clausal Supplement: 0
#
# Clause: To indicate the ideal proportion , and reveal sculptural mass and the dominating spirit ,.
# Clausal Supplement: 0
#
# Clause: To bid against yourself.
# Clausal Supplement: 0
#
# Clause: That it happened on Christmas , he added , ` `.
# Clausal Supplement: 1
#
# Clause: To say this series is n't for viewers with delicate constitutions.
# Clausal Supplement: 0
#
# Clause: To achieve multipurpose utilization of the country 's resources.
# Clausal Supplement: 0
#
# Clause: To try and impose some special restrictions and sanctions on news organizations because they 're covering a trial.
# Clausal Supplement: 0
#
# Clause: That the person be dead.
# Clausal Supplement: 0
#
# Clause: That the fashion conversation would be reduced to something so simplistic.
# Clausal Supplement: 0
#
# Clause: To study the self.
# Clausal Supplement: 0
#
# Clause: To finance the costs of these benefits by.
# Clausal Supplement: 0
#
# Clause: To use   wrong   to get rid of an unwanted behavior.
# Clausal Supplement: 0
#
# Clause: To focus first on community , anywhere in American society at the turn of the millennium ,.
# Clausal Supplement: 0
#
# Clause: To go in at half - time 19 - 6.
# Clausal Supplement: 0
#
# Clause: That he became a writer at all.
# Clausal Supplement: 0
#
# Clause: To cut off loans.
# Clausal Supplement: 0
#
# Clause: That quick sound mixing.
# Clausal Supplement: 0
#
# Clause: To remove someone for anything less.
# Clausal Supplement: 0
#
# Clause: To get three top order batsmen out.
# Clausal Supplement: 0
#
# Clause: To say that chop suey gets a bad rap.
# Clausal Supplement: 0
#
# Clause: That the Broncos leave this football season on a gurney.
# Clausal Supplement: 0
#
# Clause: That the birds in Hitchcock 's film were Jessica Tandy 's punishment of Tippi Hedren 's lust for Tandy 's son.
# Clausal Supplement: 0
#
# Clause: To view the Getty 's two photography collections at the same time.
# Clausal Supplement: 0
#
# Clause: That the forward - looking Houston Grand Opera has done so.
# Clausal Supplement: 0
#
# Clause: That she will be an Army private at such an age.
# Clausal Supplement: 0
#
# Clause: That the new president already during the installation ceremony appealed for unity.
# Clausal Supplement: 0
#
# Clause: That this kind of barbarism took place.
# Clausal Supplement: 0
#
# Clause: To turn the idea into a company  .
# Clausal Supplement: 0
#
# Clause: To carry more the weapons.
# Clausal Supplement: 0
#
# Clause: To return to   normal  .
# Clausal Supplement: 0
#
# Clause: That the company undertook a survey of 1,000 homeowners to find out this information.
# Clausal Supplement: 0
#
# Clause: To reach that -LRB- quickly -RRB- with the national squad.
# Clausal Supplement: 0
#
# Clause: To assume that private enterprise can come in and save a school system and run it better than good educators.
# Clausal Supplement: 0
#
# Clause: To insist that regular - season games do n't matter.
# Clausal Supplement: 0
#
# Clause: To say that yesterday people went to work and that the bread - maker made bread.
# Clausal Supplement: 0
#
# Clause: To have a success on Broadway.
# Clausal Supplement: 0
#
# Clause: To make an issue of a golfer 's witless crack about fried chicken , watermelon and collard greens.
# Clausal Supplement: 0
#
# Clause: To talk of eras on Wall Street.
# Clausal Supplement: 0
#
# Clause: To go against them.
# Clausal Supplement: 0
#
# Clause: To say the Kings lost the series on that play.
# Clausal Supplement: 0
#
# Clause: To do anything otherwise.
# Clausal Supplement: 0
#
# Clause: To avoid being.
# Clausal Supplement: 0
#
# Clause: To control population growth during the next decades and reduce carbon dioxide emissions , especially in developing countries ,.
# Clausal Supplement: 0
#
# Clause: That he earned a $ 1,170,000 check that was more than what he made in his first 12 years on the Tour.
# Clausal Supplement: 0
#
# Clause: That the measure has reached the Duma 's floor , however ,.
# Clausal Supplement: 0
#
# Clause: To say performer Jim Bailey has a slightly unusual career _ even for an unusual industry like show business _.
# Clausal Supplement: 0
#
# Clause: To assume that voluntary charity will raise enough revenues to meet this standard.
# Clausal Supplement: 0
#
# Clause: To let them come back into Icelandic waters.
# Clausal Supplement: 0
#
# Clause: To bring in somebody new like that , who does n't even know the party 's procedures , in this two - year period when we have an open presidential election ,.
# Clausal Supplement: 1
#
# Clause: To feel remorse.
# Clausal Supplement: 0
#
# Clause: To have such a strong mix of tests , one - day internationals and Twenty20s.
# Clausal Supplement: 0
#
# Clause: That the Tarahumara have managed to survive as the largest native tribe in the border state of Chihuahua.
# Clausal Supplement: 0
#
# Clause: To walk around Fenway Park on a game night with Werner.
# Clausal Supplement: 0
#
# Clause: That the 6 - year - old series , which averages 6.9 million viewers each week , consistently beats the horny teenyboppers on Creek and demon - slaying gang on ` ` Angel ''.
# Clausal Supplement: 1
#
# Clause: That it was so widespread in Jacksonville last week.
# Clausal Supplement: 0
#
# Clause: To favor older systems over new alternatives out of loyalty.
# Clausal Supplement: 0
#
# Clause: To insist that we maintain this traditional understanding of marriage.
# Clausal Supplement: 0
#
# Clause: To outrun a winger for your first try.
# Clausal Supplement: 0
#
# Clause: To act them.
# Clausal Supplement: 0
#
# Clause: To see these guys getting off.
# Clausal Supplement: 0
#
# Clause: To say that cats are a little demanding.
# Clausal Supplement: 0
#
# Clause: To face Greg Maddux during this extraordinary stretch of his career.
# Clausal Supplement: 0
#
# Clause: To love Disneyland.
# Clausal Supplement: 0
#
# Clause: To watch your children hanging 10 -LRB-.
# Clausal Supplement: 0
#
# Clause: To fight for a country 's honor.
# Clausal Supplement: 0
#
# Clause: To be down two sets and a break in the third against a guy you ' ve never beaten in six matches.
# Clausal Supplement: 0
#
# Clause: To take part in the Olympics again.
# Clausal Supplement: 0
#
# Clause: To do away with taxes on Stock dividends.
# Clausal Supplement: 0
#
# Clause: To have the Nuggets come so close.
# Clausal Supplement: 0
#
# Clause: That this jury seems to be having difficulty.
# Clausal Supplement: 0
#
# Clause: To get them to read something this dense on fees.
# Clausal Supplement: 0
#
# Clause: To pull that off.
# Clausal Supplement: 0
#
# Clause: To be there two years.
# Clausal Supplement: 0
#
# Clause: To win the nationals.
# Clausal Supplement: 0
#
# Clause: To choose Paris.
# Clausal Supplement: 0
#
# Clause: To safeguard state sovereignty and territorial integrity and realize complete reunification of the motherland at an early date.
# Clausal Supplement: 0
#
# Clause: To say the ending is disappointing.
# Clausal Supplement: 0
#
# Clause: That he 's a manufactured point guard.
# Clausal Supplement: 0
#
# Clause: That she is not married.
# Clausal Supplement: 0
#
# Clause: To take that away.
# Clausal Supplement: 0
#
# Clause: That the moth story has become so well.
# Clausal Supplement: 0
#
# Clause: To not include the governor and then turn around and try to find a scapegoat for their loss.
# Clausal Supplement: 0
#
# Clause: To call him a diligent shopper.
# Clausal Supplement: 0
#
# Clause: To interview the man whom Ayatollah Khomeini once anointed as his chosen successor.
# Clausal Supplement: 0
#
# Clause: To exist necessarily.
# Clausal Supplement: 0
#
# Clause: To be able to go to one place , enter search terms and get information from two databases.
# Clausal Supplement: 0
#
# Clause: To find them again.
# Clausal Supplement: 0
#
# Clause: That the list may be perceived as even close to definitive.
# Clausal Supplement: 0
#
# Clause: That he , a movie star , shut down the town while searching to quench his thirst.
# Clausal Supplement: 0
#
# Clause: To stifle them.
# Clausal Supplement: 0
#
# Clause: To accept something like that.
# Clausal Supplement: 0
#
# Clause: That the Indians , who had won six straight and 11 of 14 , took a major blow to its wild - card aspirations.
# Clausal Supplement: 1
#
# Clause: To break a bone in your body.
# Clausal Supplement: 0
#
# Clause: To say this could be wiped out in a couple of years.
# Clausal Supplement: 0
#
# Clause: To cut them out.
# Clausal Supplement: 0
#
# Clause: To be ` ` blur  .
# Clausal Supplement: 0
#
# Clause: That he was astute enough to land Dirk Nowitzki , the best foreign NBA player to date ,.
# Clausal Supplement: 0
#
# Clause: To change my style of play.
# Clausal Supplement: 0
#
# Clause: That the Bears still had a chance for the playoffs.
# Clausal Supplement: 0
#
# Clause: To watch Monster House   in Real D , Bruer said ,.
# Clausal Supplement: 1
#
# Clause: To believe the government 's version of facts ,   Ware wrote ,  .
# Clausal Supplement: 1
#
# Clause: That she is able to make Sonia a likable character.
# Clausal Supplement: 0
#
# Clause: That the West Indies , who lead the three - match series 1 - 0 , were still in the match.
# Clausal Supplement: 1
#
# Clause: That the Iberians should be buried by Spain 's subsequent history.
# Clausal Supplement: 0
#
# Clause: To attend both the VIP reception   and dinner.
# Clausal Supplement: 0
#
# Clause: To blame Albert for the brawl rather than the pitchers who were intentionally throwing at him.
# Clausal Supplement: 0
#
# Clause: To say that he is sorry for the wretched deeds of earlier administrations.
# Clausal Supplement: 0
#
# Clause: To state the problem.
# Clausal Supplement: 0
#
# Clause: That he does n't like to consult with anybody outside his small circle of old friends.
# Clausal Supplement: 0
#
# Clause: To find out that more than half of the American public believes this.
# Clausal Supplement: 0
#
# Clause: To get to know a lot of these women and hear their stories.
# Clausal Supplement: 0
#
# Clause: To embrace -LRB- my heritage -RRB-.
# Clausal Supplement: 0
#
# Clause: To be able to put a Purple Heart on a World War II veteran.
# Clausal Supplement: 0
#
# Clause: To control images -- shoot , edit , print them --.
# Clausal Supplement: 1
#
# Clause: To understand Collins ' life and death.
# Clausal Supplement: 0
#
# Clause: To lessen his wife 's time in the kitchen , the AGA.
# Clausal Supplement: 0
#
# Clause: To think we should just beat them because they do n't have a good record or because they have younger players.
# Clausal Supplement: 0
#
# Clause: To be called a communist in deeply Catholic Timor.
# Clausal Supplement: 0
#
# Clause: To overlook our passing game.
# Clausal Supplement: 0
#
# Clause: That the health - care overhaul passed by Congress last month continues the ban on federal funding for abortions -- expanded it , by some accounts --.
# Clausal Supplement: 0
#
# Clause: To score nine against any opposition.
# Clausal Supplement: 0
#
# Clause: To know we can bring them out.
# Clausal Supplement: 0
#
# Clause: To go to Bruno 's , in the Mission district , or the Up and Down Club in Soma , the South of Market area ,.
# Clausal Supplement: 0
#
# Clause: To say that , ' I am open - minded , '.
# Clausal Supplement: 0
#
# Clause: That the gangs are capable of instilling such terror in community members.
# Clausal Supplement: 0
#
# Clause: That these technologies later.
# Clausal Supplement: 0
#
# Clause: That the 6 - foot-3 infielder turned back Father Time and mutant cell growth on his spine , too ,.
# Clausal Supplement: 0
#
# Clause: To have a program that was n't serious , that did n't have consequences or sanctions for not taking a step up in life ,.
# Clausal Supplement: 0
#
# Clause: To spend a day in a divorce court.
# Clausal Supplement: 0
#
# Clause: That the terrorists attacked women.
# Clausal Supplement: 0
#
# Clause: To lose 5.8 million dollars -LRB- overall -RRB-.
# Clausal Supplement: 0
#
# Clause: To be a human being.
# Clausal Supplement: 0
#
# Clause: To have great friends in your life.
# Clausal Supplement: 0
#
# Clause: To suggest he would betray his country or do anything in any way to damage American national security interests.
# Clausal Supplement: 0
#
# Clause: To safeguard teachers ' and students ' health , schools.
# Clausal Supplement: 0
#
# Clause: To just have him obsessed with her.
# Clausal Supplement: 0
#
# Clause: To go get replacement players.
# Clausal Supplement: 0
#
# Clause: To have to go through this -LRB- court -RRB- process at this stage of their career.
# Clausal Supplement: 0
#
# Clause: To make both free throws in that situation and hit nothing but net.
# Clausal Supplement: 0
#
# Clause: To live as a pessimist.
# Clausal Supplement: 0
#
# Clause: To play for Summitt.
# Clausal Supplement: 0
#
# Clause: To have all this happen at the last minute.
# Clausal Supplement: 0
#
# Clause: To Live  .
# Clausal Supplement: 0
#
# Clause: That the story is now history.
# Clausal Supplement: 0
#
# Clause: To under - fund our educational system.
# Clausal Supplement: 0
#
# Clause: That a Chinese company would move so decisively into the center of a takeover attempt by BHP.
# Clausal Supplement: 0
#
# Clause: To have so many diseases cause so many problems over such a short period of time.
# Clausal Supplement: 0
#
# Clause: To preserve something that is not destroyed.
# Clausal Supplement: 0
#
# Clause: That those black - and - white promotional vignettes showing players in various adoring poses with the Lombardi Trophy.
# Clausal Supplement: 0
#
# Clause: That he was rusty.
# Clausal Supplement: 0
#
# Clause: To improve rural teacher 's quality.
# Clausal Supplement: 0
#
# Clause: To peer out into the landscape.
# Clausal Supplement: 0
#
# Clause: To ride tempo on the mountains and end up with only five guys.
# Clausal Supplement: 0
#
# Clause: To play with Santos again.
# Clausal Supplement: 0
#
# Clause: To have a stockpile.
# Clausal Supplement: 0
#
# Clause: That the Web is mostly supported by ad revenues.
# Clausal Supplement: 0
#
# Clause: That it used autopsy results in determining cause of death.
# Clausal Supplement: 0
#
# Clause: To suggest that the prosecution of Powers Fasteners is motivated by anything other than the pursuit of justice -- not only for the victims , but for the Commonwealth as a whole --.
# Clausal Supplement: 0
#
# Clause: To me that call.
# Clausal Supplement: 0
#
# Clause: To be among this youth.
# Clausal Supplement: 0
#
# Clause: That she managed to do so.
# Clausal Supplement: 0
#
# Clause: To find out it 's 375 million years old.
# Clausal Supplement: 0
#
# Clause: That the Supreme Court agreed to become involved in one of the most delicate and politically charged issues facing this country.
# Clausal Supplement: 0
#
# Clause: That the government would allow the reports to be.
# Clausal Supplement: 0
#
# Clause: To say that 's a regret.
# Clausal Supplement: 0
#
# Clause: That they are putting people at risk.
# Clausal Supplement: 0
#
# Clause: To say there 's not assimilation because they 're close to their home country.
# Clausal Supplement: 0
#
# Clause: To oppose that idea.
# Clausal Supplement: 0
#
# Clause: To control nature.
# Clausal Supplement: 0
#
# Clause: To have the rest of the world treat us like that.
# Clausal Supplement: 0
#
# Clause: That it could be Anderson 's sub.
# Clausal Supplement: 0
#
# Clause: To say it is simply about high ticket prices -LRB- the case throughout the entire sports industry -RRB- and the club 's decades - long adherence to making a buck.
# Clausal Supplement: 0
#
# Clause: To then get them up to a standard where they have become a Premiership winning team.
# Clausal Supplement: 0
#
# Clause: To be able to have that kind of house in the city.
# Clausal Supplement: 0
#
# Clause: To save the lives of human beings , to save the hostages , I.
# Clausal Supplement: 1
#
# Clause: That it ever does.
# Clausal Supplement: 0
#
# Clause: That both the FIA and the teams could have faced serious legal difficulties in the United States had they not observed their respective rules and contractual obligations -LRB- particularly had there been any kind of accident -RRB- , the Senate.
# Clausal Supplement: 0
#
# Clause: To have your peers respect you and respect your game.
# Clausal Supplement: 0
#
# Clause: To spend another year on Bush.
# Clausal Supplement: 0
#
# Clause: To win the French Open.
# Clausal Supplement: 0
#
# Clause: To risk losing a president over a fumble.
# Clausal Supplement: 0
#
# Clause: To say that Baltimore put on the dog for Ripken this week.
# Clausal Supplement: 0
#
# Clause: To be known with no top on.
# Clausal Supplement: 0
#
# Clause: To talk details.
# Clausal Supplement: 0
#
# Clause: That the Seminoles needed a win against perennial ACC cellar dweller Duke to get back on course.
# Clausal Supplement: 0
#
# Clause: That he navigated the rock - hard fairways , beguiling swales , and tricky crosswinds coming off the Firth of Tay to post 22 birdies against three measly bogeys.
# Clausal Supplement: 1
#
# Clause: That he never developed into a major artist.
# Clausal Supplement: 0
#
# Clause: To have drivers pick us out nationwide.
# Clausal Supplement: 0
#
# Clause: To be able to launch my own career.
# Clausal Supplement: 0
#
# Clause: To call it a bed.
# Clausal Supplement: 0
#
# Clause: To end it that way.
# Clausal Supplement: 0
#
# Clause: To end life in such a way.
# Clausal Supplement: 0
#
# Clause: To play at this level for so many years.
# Clausal Supplement: 0
#
# Clause: To praise Wolfowitz.
# Clausal Supplement: 0
#
# Clause: To publish this newspaper in the Inland Empire , where I ' ve lived most of my life ,.
# Clausal Supplement: 0
#
# Clause: To play anyone.
# Clausal Supplement: 0
#
# Clause: That it will also be prosecuting both the landowners and companies.
# Clausal Supplement: 0
#
# Clause: To have it all donated to the public.
# Clausal Supplement: 0
#
# Clause: That the two sides have a long way to go before they see a broad cease - fire.
# Clausal Supplement: 0
#
# Clause: To see the Canadian flag flying here at the World Golf Hall of Fame.
# Clausal Supplement: 0
#
# Clause: That she chose to break through as she does in ` ` Afterglow '' _ or , for that matter , that she chose to be in ` ` Afterglow '' _.
# Clausal Supplement: 0
#
# Clause: To do that again.
# Clausal Supplement: 0
#
# Clause: To be on the medal podium for a 5 K.
# Clausal Supplement: 0
#
# Clause: That he did not turn out to be a wonder horse at 3.
# Clausal Supplement: 0
#
# Clause: To tune in now.
# Clausal Supplement: 0
#
# Clause: To extract a few grams of gold and risk ruining that area.
# Clausal Supplement: 0
#
# Clause: To pass one 's life alone.
# Clausal Supplement: 0
#
# Clause: To see the eyes of someone who 's having a good meal.
# Clausal Supplement: 0
#
# Clause: To agree to such a program.
# Clausal Supplement: 0
#
# Clause: That it did.
# Clausal Supplement: 0
#
# Clause: To say it 's tough to play at Tiger Stadium at night.
# Clausal Supplement: 0
#
# Clause: To feel insecure.
# Clausal Supplement: 0
#
# Clause: To hold the merger hostage , he said ,  .
# Clausal Supplement: 1
#
# Clause: That the Lightning plays tonight in Philadelphia and the Devils in Montreal also.
# Clausal Supplement: 0
#
# Clause: That he was one of Ireland 's most promising golfers and represented another generation of this celebrated golfing family.
# Clausal Supplement: 0
#
# Clause: To overcome the United Nations ' present and likely continuing financial crisis , clear - sighted and innovative thinking.
# Clausal Supplement: 0
#
# Clause: To say his language is salty.
# Clausal Supplement: 0
#
# Clause: That he turned out to be wrong.
# Clausal Supplement: 0
#
# Clause: To say that I do n't like the media.
# Clausal Supplement: 0
#
# Clause: To have foreign partners.
# Clausal Supplement: 0
#
# Clause: To be where he is now and the amount of years he 's played.
# Clausal Supplement: 0
#
# Clause: That they should prove so hardy in a deeply conservative Congress _ at least so far _.
# Clausal Supplement: 0
#
# Clause: To organise the snowboard competition.
# Clausal Supplement: 0
#
# Clause: To score four goals in a half.
# Clausal Supplement: 0
#
# Clause: To build the needed side roads and turnarounds.
# Clausal Supplement: 0
#
# Clause: To take these elderly and disabled people and all of a sudden change the rules.
# Clausal Supplement: 0
#
# Clause: To pitch at this level in front of family and friends.
# Clausal Supplement: 0
#
# Clause: To be a homeowner at 23.
# Clausal Supplement: 0
#
# Clause: To be placed in a position of defending elitism.
# Clausal Supplement: 0
#
# Clause: To have four in the same year.
# Clausal Supplement: 0
#
# Clause: To be playing for the Europa League.
# Clausal Supplement: 0
#
# Clause: That officers.
# Clausal Supplement: 0
#
# Clause: To get so many golds in an Olympics.
# Clausal Supplement: 0
#
# Clause: To see the rapid growth in both quality and quantity.
# Clausal Supplement: 0
#
# Clause: To go out there and perform on a day like today when it was crucial.
# Clausal Supplement: 0
#
# Clause: To encounter two youngsters drawn with such tender regard for their real and complicated humanity.
# Clausal Supplement: 0
#
# Clause: That this should reach the point of getting the DA 's office so dramatically.
# Clausal Supplement: 0
#
# Clause: To keep on going on about the same thing.
# Clausal Supplement: 0
#
# Clause: To bring him to court.
# Clausal Supplement: 0
#
# Clause: To doubt the activities of the FSB.
# Clausal Supplement: 0
#
# Clause: To make them smile and make their life a little bit better ; this.
# Clausal Supplement: 0
#
# Clause: That the Giants will see the Phillies for the first time.
# Clausal Supplement: 0
#
# Clause: To put a new twist on an old line from Franken 's   Saturday Night Live character , Stuart Smalley , proving they 're good enough and smart enough.
# Clausal Supplement: 0
#
# Clause: To do that on a national basis.
# Clausal Supplement: 0
#
# Clause: To come from 14th and win here.
# Clausal Supplement: 0
#
# Clause: To wait until the IAEA finds the nuclear weapons ....
# Clausal Supplement: 0
#
# Clause: To be leading the field off.
# Clausal Supplement: 0
#
# Clause: To say that Hollywood producers are not trustworthy.
# Clausal Supplement: 0
#
# Clause: To spend a day in Terry 's World.
# Clausal Supplement: 0
#
# Clause: To be the best in the world.
# Clausal Supplement: 0
#
# Clause: To end with the cheaters.
# Clausal Supplement: 0
#
# Clause: To blame the weather.
# Clausal Supplement: 0
#
# Clause: To be the gold medalist.
# Clausal Supplement: 0
#
# Clause: To be able to play in this game.
# Clausal Supplement: 0
#
# Clause: That he could not head off the fight , Vincent said ,.
# Clausal Supplement: 1
#
# Clause: To say that such differences are n't real ,   Clark later said in an interview ,  .
# Clausal Supplement: 0
#
# Clause: To mention John Dos Passos.
# Clausal Supplement: 0
#
# Clause: To read the study.
# Clausal Supplement: 0
#
# Clause: To deprive him of this option ... solely to satisfy the convenience of another citizen ,.
# Clausal Supplement: 0
#
# Clause: To bump the fuel economy up to 50 mpg.
# Clausal Supplement: 0
#
# Clause: To say that tourism is unstoppable.
# Clausal Supplement: 0
#
# Clause: To make a loan in these circumstances.
# Clausal Supplement: 0
#
# Clause: To write about what it was like there.
# Clausal Supplement: 0
#
# Clause: To see 20 original works by the mid-20th - century artist Harry Bertoia -LRB- 1915 - 1978 -RRB-.
# Clausal Supplement: 0
#
# Clause: To be one of two teams to advance to the second round.
# Clausal Supplement: 0
#
# Clause: That the issue of the economy is anywhere close to even between the candidates.
# Clausal Supplement: 0
#
# Clause: To have one person in the family stricken with cancer.
# Clausal Supplement: 0
#
# Clause: To say man is bad because he is selfish.
# Clausal Supplement: 0
#
# Clause: That he revisited the playoffs twice as an assistant coach at New Jersey before becoming the head honcho in L.A. in 1995.
# Clausal Supplement: 0
#
# Clause: That the Lightning is still in the New Jersey area and has no other games there the rest of the season also.
# Clausal Supplement: 0
#
# Clause: To be here and feel this atmosphere.
# Clausal Supplement: 0
#
# Clause: To not be able to speak my side of this for an entire year.
# Clausal Supplement: 0
#
# Clause: To win the Tour once.
# Clausal Supplement: 0
#
# Clause: To say we 're insensitive or irresponsible.
# Clausal Supplement: 0
#
# Clause: That the Fed has entered into so many new areas.
# Clausal Supplement: 0
#
# Clause: To see that among Rhys ' many alternate title choices for this classic were   Story of the First Mrs. Rochester ,   Le Rouge et le Noir and   Wild Sea of Wrecks.
# Clausal Supplement: 0
#
# Clause: That these capabilities are available to PC users for about $ 35.
# Clausal Supplement: 0
#
# Clause: To get through that with the stats he did.
# Clausal Supplement: 0
#
# Clause: To be included in the missile package that will be mounted aboard the Kidd - class destroyers.
# Clausal Supplement: 0
#
# Clause: That she had destroyed an antique.
# Clausal Supplement: 0
#
# Clause: To reach a final again.
# Clausal Supplement: 0
#
# Clause: That they live in a cocoon of safety and ca n't fathom the reality of war.
# Clausal Supplement: 0
#
# Clause: To do one round of a professional dance competition , five dances of a minute and a half ,.
# Clausal Supplement: 0
#
# Clause: To change hearts and minds and ... the attitudes individuals have toward their jobs.
# Clausal Supplement: 0
#
# Clause: To think -LRB- white people -RRB- are n't interested in our culture.
# Clausal Supplement: 0
#
# Clause: That the ABC drama -LRB- beginitalic -RRB- Life As We Know It -LRB- enditalic -RRB- spends a lot of its time dealing with sex , teen and otherwise ,.
# Clausal Supplement: 0
#
# Clause: To have Cathy be at once liberated from her straight - jacket and simultaneously bitter and sad about her condition.
# Clausal Supplement: 0
#
# Clause: That the lush , Beatlesque ` ` Benjamin '' offers a fresh twist on standard rock ballad form.
# Clausal Supplement: 0
#
# ...
# Clausal Supplement: 0
#
# Clause: To have it laid out explicitly in a memo.
# Clausal Supplement: 0
#
# Clause: To note the frequency of that formulation.
# Clausal Supplement: 0
#
# Clause: That a vintage California winery makes a top - flight chardonnay.
# Clausal Supplement: 0
#
# Clause: To discern a common denominator in all these moves.
# Clausal Supplement: 0
#
# Clause: That the Braves , who were swept last year by the Yankees , have not won a Series game since then.
# Clausal Supplement: 1
#
# Clause: To adapt a book that is more than 100 years old to a contemporary setting.
# Clausal Supplement: 0
#
# Clause: To lose to them.
# Clausal Supplement: 0
#
# Clause: That the Tigers won.
# Clausal Supplement: 0
#
# Clause: To keep these kids in fear and propagate the legitimacy of these threats.
# Clausal Supplement: 0
#
# Clause: To say that a prosecutor may abuse witnesses and violate the law in pursuit of his quarry.
# Clausal Supplement: 0
#
# Clause: To avoid actions that may ruin mutual trust and reconciliation.
# Clausal Supplement: 0
#
# Clause: To make that charge recklessly.
# Clausal Supplement: 0
#
# Clause: That the leading Palestinian politicians feel the need to find out the facts for themselves.
# Clausal Supplement: 0
#
# Clause: That the New Orleans Saints play up or down to their level of competition.
# Clausal Supplement: 0
#
# Clause: To say Kentucky is limping into the tournament.
# Clausal Supplement: 0
#
# Clause: That this hardening will break the strikers ' will.
# Clausal Supplement: 0
#
# Clause: That it happened in his first year with Miami after a trade from New England.
# Clausal Supplement: 0
#
# Clause: To win two Test matches in almost two days each.
# Clausal Supplement: 0
#
# Clause: To classify it as intentionally misleading , sinister or racist.
# Clausal Supplement: 0
#
# Clause: To be able to come back here and.
# Clausal Supplement: 0
#
# Clause: To raise $ 20 million to $ 30 million.
# Clausal Supplement: 0
#
# Clause: To say that Northern Ireland 's Protestants have an image problem.
# Clausal Supplement: 0
#
# Clause: To descend into that idyllic valley.
# Clausal Supplement: 0
#
# Clause: To take action now.
# Clausal Supplement: 0
#
# Clause: To cut a minor character from the first book and then find he 's pivotal in the sixth.
# Clausal Supplement: 0
#
# Clause: To have those conversations with him and work with him on an emotional and close piece.
# Clausal Supplement: 0
#
# Clause: To achieve the long - term goal of two states living side by side , an initial step being proposed by the U.S. administration ,.
# Clausal Supplement: 0
#
# Clause: To ignore the will of the people.
# Clausal Supplement: 0
#
# Clause: To think that you 're going to change him or do anything to him personally.
# Clausal Supplement: 0
#
# Clause: To play 100 tests.
# Clausal Supplement: 0
#
# Clause: That it ended according to the schedule.
# Clausal Supplement: 0
#
# Clause: To visit the Yasukuni Shrine.
# Clausal Supplement: 0
#
# Clause: To allow the product to remain on the market while using its consumption as a pretense to attempt a legal expropriation of private resources.
# Clausal Supplement: 0
#
# Clause: That the federal government STILL does n't know exactly where the salmonella is coming from.
# Clausal Supplement: 0
#
# Clause: To train a warring nation 's soldiers.
# Clausal Supplement: 0
#
# Clause: To say it was a consular error.
# Clausal Supplement: 0
#
# Clause: To inflame ethnic hatred.
# Clausal Supplement: 0
#
# Clause: That the dispute had even tripped up Sen. Hillary Rodham Clinton , who stumbled to answer a question about it in a presidential debate , ` `.
# Clausal Supplement: 1
#
# Clause: To have the President.
# Clausal Supplement: 0
#
# Clause: That these expansive ads , which can be stopped with a single click , are distracting.
# Clausal Supplement: 1
#
# Clause: To tie it to print or the concept of a newspaper.
# Clausal Supplement: 0
#
# Clause: To replace Serbia 's heavy hand on Albanians with an autonomous or independent Kosovo 's heavy hand on local Serbs.
# Clausal Supplement: 0
#
# Clause: To call the thunderstorm around baseball 's leading home - run hitter a   controversy  .
# Clausal Supplement: 0
#
# Clause: To say he was growing fidgety.
# Clausal Supplement: 0
#
# Clause: To get the pole.
# Clausal Supplement: 0
#
# Clause: To be at the office.
# Clausal Supplement: 0
#
# Clause: That the secretary of the Interior could stand atop Hoover Dam last week and proclaim that a relatively minor readjustment in the use of Colorado River water would end the water wars.
# Clausal Supplement: 0
#
# Clause: To come back the way we did against a team like Croatia.
# Clausal Supplement: 0
#
# Clause: That he understands this at age 21.
# Clausal Supplement: 0
#
# Clause: To beat her.
# Clausal Supplement: 0
#
# Clause: That the band 's drive still surprises listeners who pigeonhole Snow Patrol as a disciple of Coldplay because of ` ` Run ''.
# Clausal Supplement: 0
#
# Clause: To do that , clear direction , clear vision , clear leadership.
# Clausal Supplement: 0
#
# Clause: To suggest that Lieberman is hesitant to stand up for what he believes in and fight for it on the floor.
# Clausal Supplement: 0
#
# Clause: To say that a drug can guarantee good memory.
# Clausal Supplement: 0
#
# Clause: To try to stop a musical group from performing only because gay people like to listen to them.
# Clausal Supplement: 0
#
# Clause: To be the fastest movie to reach that mark.
# Clausal Supplement: 0
#
# Clause: To focus on one area.
# Clausal Supplement: 0
#
# Clause: To compare this Honeymooners   to the Jackie Gleason show.
# Clausal Supplement: 0
#
# Clause: To perceive that the cart puts him _ with his condition _ at a competitive advantage.
# Clausal Supplement: 0
#
# Clause: To think he could have given 271 works of art to somebody who is n't even known among his friends.
# Clausal Supplement: 0
#
# Clause: To be a player in this high - stakes board game.
# Clausal Supplement: 0
#
# Clause: That it made little use of his bachelor 's degree in political science.
# Clausal Supplement: 0
#
# Clause: To walk these streets.
# Clausal Supplement: 0
#
# Clause: To say that things are not moving forward.
# Clausal Supplement: 0
#
# Clause: To say that people had very strong emotional feelings about this ,.
# Clausal Supplement: 0
#
# Clause: That he is not better.
# Clausal Supplement: 0
#
# Clause: That the wreck of the Sunset Limited occurred in Arizona.
# Clausal Supplement: 0
#
# Clause: To say the LaCrosse handles better than the ES350.
# Clausal Supplement: 0
#
# Clause: That it all leads to a final rematch with Teddy KGB.
# Clausal Supplement: 0
#
# Clause: To characterize it in any other way.
# Clausal Supplement: 0
#
# Clause: That they go on to become top leaders in their fields.
# Clausal Supplement: 0
#
# Clause: To really try to fool Mother Nature and try to keep animals immortal by replicating them.
# Clausal Supplement: 0
#
# Clause: That this was possible.
# Clausal Supplement: 0
#
# Clause: That he was able to get through it.
# Clausal Supplement: 0
#
# Clause: To clean itself up , the first thing the Olympics.
# Clausal Supplement: 0
#
# Clause: To hope for a smaller number.
# Clausal Supplement: 0
#
# Clause: To assume that just because we have levees makes us more liable.
# Clausal Supplement: 0
#
# Clause: To be one of the last four.
# Clausal Supplement: 0
#
# Clause: That she was far more entertain ing than Patterson.
# Clausal Supplement: 0
#
# Clause: To watch Crudup and Danes -LRB- off - screen lovers with a somewhat scandalous backstory of their own -RRB- play Ned and Maria playing Othello and Desdemona.
# Clausal Supplement: 0
#
# Clause: That they stayed close to the Spurs throughout.
# Clausal Supplement: 0
#
# Clause: To have those two qualities in one package.
# Clausal Supplement: 0
#
# Clause: To   go postal ,   according to the Webster 's New World College Dictionary ,.
# Clausal Supplement: 0
#
# Clause: To force people to live a certain type of personal life or else ,.
# Clausal Supplement: 0
#
# Clause: That it came at the Olympic trials.
# Clausal Supplement: 0
#
# Clause: That American homes face more leverage than they once.
# Clausal Supplement: 0
#
# Clause: To call it a bedroom.
# Clausal Supplement: 0
#
# Clause: To have the two of them here , plus a third Queen ,.
# Clausal Supplement: 0
#
# Clause: To reduce the complexities or painful ambiguities of the issue to slogans or historical shorthand.
# Clausal Supplement: 0
#
# Clause: That she is now her ex - husband 's boss.
# Clausal Supplement: 0
#
# Clause: To finance and manage your reunion in a money - smart way , the key.
# Clausal Supplement: 0
#
# Clause: To write about columnist Marjorie Williams.
# Clausal Supplement: 0
#
# Clause: To get this with six games coming up on the road.
# Clausal Supplement: 0
#
# Clause: To have so many players in the sin bin so often and the number of penalties that were blown , both sides.
# Clausal Supplement: 0
#
# Clause: To get to the final here.
# Clausal Supplement: 0
#
# Clause: To get through to the second round.
# Clausal Supplement: 0
#
# Clause: To watch a Valentino show.
# Clausal Supplement: 0
#
# Clause: To expand rapidly on the basis of name - brand products.
# Clausal Supplement: 0
#
# Clause: To focus on his skin pigmentation.
# Clausal Supplement: 0
#
# Clause: To see a tush now and then , or see somebody take a shower ,.
# Clausal Supplement: 0
#
# Clause: To see them up close and be able to talk to them.
# Clausal Supplement: 0
#
# Clause: That the United States is getting older.
# Clausal Supplement: 0
#
# Clause: That the reporters produce anything of merit under these circumstances.
# Clausal Supplement: 0
#
# Clause: To make this campaign fodder for me , because of the person I am ,.
# Clausal Supplement: 0
#
# Clause: To be given another contract this year.
# Clausal Supplement: 0
#
# Clause: To go through all the ups and downs a team goes through and watch how we became a unit and got better.
# Clausal Supplement: 0
#
# Clause: To come to a new situation where there 's a chance to step in and.
# Clausal Supplement: 0
#
# Clause: To look back on Harrick 's record at UCLA.
# Clausal Supplement: 0
#
# Clause: To find a treatment that cuts this risk in half again.
# Clausal Supplement: 0
#
# Clause: To think that she was lost and not.
# Clausal Supplement: 0
#
# Clause: To need help from other teams to get into the playoffs.
# Clausal Supplement: 0
#
# Clause: To Goldhagen the answers to these questions.
# Clausal Supplement: 0
#
# Clause: To suggest that Nebraska or anyone is going to come back year after year.
# Clausal Supplement: 0
#
# Clause: To achieve complete reunification of the motherland.
# Clausal Supplement: 0
#
# Clause: That they did so without a scratch , he says ,.
# Clausal Supplement: 1
#
# Clause: To evacuate the war - displaced people.
# Clausal Supplement: 0
#
# Clause: To have it suggested that somehow her ideas are consistent with the Ku Klux Klan ,   he said ,.
# Clausal Supplement: 1
#
# Clause: That it came at Martinsville.
# Clausal Supplement: 0
#
# Clause: To say Johnson beat the odds.
# Clausal Supplement: 0
#
# Clause: To do otherwise -- that is , to have opinions on issues -LRB- even issues utterly unrelated to gay rights -RRB- that do n't follow the left - wing line --.
# Clausal Supplement: 0
#
# Clause: To put all the blame on Capt . Cota.
# Clausal Supplement: 0
#
# Clause: To beat Stan on his best surface.
# Clausal Supplement: 0
#
# Clause: To persecute the innocent ,   Osterloh said ,.
# Clausal Supplement: 1
#
# Clause: That they still sell for about $ 10.
# Clausal Supplement: 0
#
# Clause: To promote tolerance.
# Clausal Supplement: 0
#
# Clause: To disqualify him.
# Clausal Supplement: 0
#
# Clause: To get to this point and not get the grand prize at the end.
# Clausal Supplement: 0
#
# Clause: To believe in one 's players.
# Clausal Supplement: 0
#
# Clause: To agree to share one 's sovereignty.
# Clausal Supplement: 0
#
# Clause: That the Tigers.
# Clausal Supplement: 0
#
# Clause: To condone your actions even when committed in this context.
# Clausal Supplement: 0
#
# Clause: To be on the block with Prada , the east side of the block ,   Ms. Consolo said ,.
# Clausal Supplement: 0
#
# Clause: To attribute the activities of one arm of the Chinese government to these state - owned corporations , and in turn to us ,.
# Clausal Supplement: 0
#
# Clause: That this northern province is n't better known to the rest of the world.
# Clausal Supplement: 0
#
# Clause: To accept the artist 's refusal to explain his paintings.
# Clausal Supplement: 0
#
# Clause: To be validated that way by one 's father.
# Clausal Supplement: 0
#
# Clause: To determine ahead of time that such returns will be ignored , however , unless caused by some Act of God ,.
# Clausal Supplement: 0
#
# Clause: To remember Zhao Ziyang.
# Clausal Supplement: 0
#
# Clause: To force his hand then.
# Clausal Supplement: 0
#
# Clause: To say that this official report was overshadowed by another one issued a week earlier.
# Clausal Supplement: 0
#
# Clause: That the president is willing to listen to dissenting voices such as mine.
# Clausal Supplement: 0
#
# Clause: To think about the world championship.
# Clausal Supplement: 0
#
# Clause: That the Jewish authorities or Jews were not involved.
# Clausal Supplement: 0
#
# Clause: To be completely on your own.
# Clausal Supplement: 0
#
# Clause: That he would be slain within two years.
# Clausal Supplement: 0
#
# Clause: To read the government 's case against the London - based oil company.
# Clausal Supplement: 0
#
# Clause: That the former Yugoslavia is a multi - ethnic area.
# Clausal Supplement: 0
#
# Clause: To have twins and come back to where she is now.
# Clausal Supplement: 0
#
# Clause: To calculate how many of Stumpel 's pretty passes Selanne and Kariya would put away.
# Clausal Supplement: 0
#
# Clause: To establish its authority , the Iraqi government plans to take responsibility for security in all of Iraq 's provinces by November ,   Bush.
# Clausal Supplement: 0
#
# Clause: To judge it on a scale of ` rhetoric : 8 , cosmotology : 6 '.
# Clausal Supplement: 0
#
# Clause: To subject a global network to disparate local regulatory treatment by 51 different jurisdictions.
# Clausal Supplement: 0
#
# Clause: To do big - budget movies that everybody.
# Clausal Supplement: 0
#
# Clause: To walk off the green and share that with her.
# Clausal Supplement: 0
#
# Clause: To get hard evidence.
# Clausal Supplement: 0
#
# Clause: To blame objects for the evil that people do to each other.
# Clausal Supplement: 0
#
# Clause: That they survived at all.
# Clausal Supplement: 0
#
# Clause: To get the idea that that they will suddenly turn into monetary lax - ists when they move to Frankfurt.
# Clausal Supplement: 0
#
# Clause: To do a fifth.
# Clausal Supplement: 0
#
# Clause: That the hostages were foreign travel agents looking into China tourism.
# Clausal Supplement: 0
#
# Clause: To prove mental well - being , all an applicant is required to do now.
# Clausal Supplement: 0
#
# Clause: To justify further violence.
# Clausal Supplement: 0
#
# Clause: To put the results in perspective , 40 basis points -LRB- 0.40 percent -RRB- of the UK market capitalization as of November 2005.
# Clausal Supplement: 0
#
# Clause: To win the Champions League.
# Clausal Supplement: 0
#
# Clause: To hear his words.
# Clausal Supplement: 0
#
# Clause: That the Clinton campaign has unleashed such a dizzy array of charges in a matter of days.
# Clausal Supplement: 0
#
# Clause: To be closer.
# Clausal Supplement: 0
#
# Clause: That the legislature should long ago have instituted the reforms Black now.
# Clausal Supplement: 0
#
# Clause: To have this eclipse the good news.
# Clausal Supplement: 0
#
# Clause: To have TP Mazembe in the final against the famous football team Internazionale Milano , the reigning European club champion ,.
# Clausal Supplement: 0
#
# Clause: To consider Cunningham the father of them all.
# Clausal Supplement: 0
#
# Clause: To do this without a consolidated brand.
# Clausal Supplement: 0
#
# Clause: To see him at Milan.
# Clausal Supplement: 0
#
# Clause: To buy stolen data for a second time.
# Clausal Supplement: 0
#
# Clause: That the campaign 's leadership failed to recognize that it was no longer ` ` the economy , stupid ''.
# Clausal Supplement: 0
#
# Clause: To lose four Test matches this season.
# Clausal Supplement: 0
#
# Clause: To ensure they continue to enjoy the public 's trust , various measures.
# Clausal Supplement: 0
#
# Results have been written to /content/drive/MyDrive/Colab Notebooks/Python_IvaNova_Scripts_Feb.1st,2025/txt to csv/all-annotations-joined/supplements.tsv
